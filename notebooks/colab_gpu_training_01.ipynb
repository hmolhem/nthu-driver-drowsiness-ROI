# %% [markdown]
# ## Quick Resume (Today)
#
# - Enable GPU (Runtime → Change runtime type → GPU) and run the GPU check.
# - Mount Drive, then run these in order:
#
# ```bash
# # 1) Clone or pull project
# %cd /content
# !git clone https://github.com/hmolhem/nthu-driver-drowsiness-ROI.git || true
# %cd nthu-driver-drowsiness-ROI
# !git pull
#
# # 2) Install deps (CUDA build)
# !pip install --index-url https://download.pytorch.org/whl/cu121 torch torchvision -U
# !pip install -r requirements.txt
#
# # 3) Link dataset from Drive (preferred; Drive already hosts drowsy/notdrowsy directly)
# from pathlib import Path
# root = Path('datasets')
# drive = Path('/content/drive/MyDrive/datasets')  # Expected: contains drowsy/ and notdrowsy/
# if root.is_symlink() and root.resolve() == drive:
#     print('Symlink already exists: datasets ->', drive)
# elif root.exists() and not root.is_symlink():
#     print('Local datasets directory already exists; leaving as-is.')
# elif drive.exists():
#     root.symlink_to(drive, target_is_directory=True)
#     print('✅ Symlink created: datasets -> /content/drive/MyDrive/datasets')
# else:
#     raise FileNotFoundError('Missing: /content/drive/MyDrive/datasets (should contain drowsy/, notdrowsy/)')
#
# # 4) Patch baseline YAML to Colab-friendly workers
# import yaml
# from pathlib import Path as _P
# p = _P('configs/baseline_resnet50.yaml')
# cfg = yaml.safe_load(p.read_text()); cfg.setdefault('data', {})
# cfg['data']['num_workers'] = 2; cfg['data']['data_root'] = 'datasets'; cfg['data']['pin_memory'] = True
# p.write_text(yaml.safe_dump(cfg, sort_keys=False))
# print('✅ Updated', p)
# print('data_root now:', cfg['data']['data_root'])
#
# # 5) Train (regularized recommended) and evaluate
# !python src/training/train_baseline.py --config configs/baseline_resnet50_regularized.yaml --device cuda
# !python src/eval/evaluate_checkpoint.py --config configs/baseline_resnet50_regularized.yaml --device cuda --save-fig --save-preds
# ```

# %% [markdown]
# ## Step 1: Verify GPU is Available

# %%
# Check GPU availability
# !nvidia-smi
# Out:
# Sat Nov 22 14:01:15 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   36C    P8             11W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# **Expected output:** Should show GPU info (Tesla T4, L4, or similar)
#
# **If you see an error:** Go back and enable GPU runtime!

# %% [markdown]
# ## Step 2: Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Action required:** Click the link and authorize access to your Google Drive

# %% [markdown]
# ## Step 3: Clone Project from GitHub

# %%
# %cd /content
# !git clone https://github.com/hmolhem/nthu-driver-drowsiness-ROI.git
# %cd nthu-driver-drowsiness-ROI
# !git status
# Out:
# /content
# fatal: destination path 'nthu-driver-drowsiness-ROI' already exists and is not an empty directory.
# /content/nthu-driver-drowsiness-ROI
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# **Expected:** Shows "On branch main" and clean working tree

# %% [markdown]
# ## Step 4: Set Up Dataset Symlink
#
# This links your Drive dataset to the project folder

# %%
# Create datasets directory
# !mkdir -p datasets

# Create symlink to your Drive dataset
# Adjust the path if your dataset is in a different location
# !ln -s /content/drive/MyDrive/datasets/ datasets/

# Create symlinks for drowsy and notdrowsy folders
# !ln -s /content/drive/MyDrive/datasets/drowsy datasets/drowsy
# !ln -s /content/drive/MyDrive/datasets/notdrowsy datasets/notdrowsy

# %%
# Verify the symlink works
# !ls -lh datasets/
# !ls datasets/drowsy/ | head -3
# !ls datasets/notdrowsy/ | head -3
# Out:
# total 0
# lrwxrwxrwx 1 root root 38 Nov 22 14:04 drowsy -> /content/drive/MyDrive/datasets/drowsy
# lrwxrwxrwx 1 root root 41 Nov 22 14:04 notdrowsy -> /content/drive/MyDrive/datasets/notdrowsy
# 001_glasses_sleepyCombination_1000_drowsy.jpg
# 001_glasses_sleepyCombination_1001_drowsy.jpg
# 001_glasses_sleepyCombination_1002_drowsy.jpg
# 001_glasses_nonsleepyCombination_0_notdrowsy.jpg
# 001_glasses_nonsleepyCombination_1000_notdrowsy.jpg
# 001_glasses_nonsleepyCombination_1001_notdrowsy.jpg

# %% [markdown]
# **Expected:** Should list 3 image files from drowsy folder
#
# **If error:** Adjust the path in the `ln -s` command to match your Drive structure

# %% [markdown]
# ## Step 5: Verify Data Splits

# %%
# Check splits exist
# %cd nthu-driver-drowsiness-ROI
# !ls -lh data/splits/
# !head -3 data/splits/train.csv
# Out:
# /content/nthu-driver-drowsiness-ROI
# total 13M
# -rw-r--r-- 1 root root 6.5M Nov 22 14:01 manifest_with_splits.csv
# -rw-r--r-- 1 root root 2.2M Nov 22 14:01 test.csv
# -rw-r--r-- 1 root root 2.6M Nov 22 14:01 train.csv
# -rw-r--r-- 1 root root 1.9M Nov 22 14:01 val.csv
# filename,label,subject,glasses,behavior,frame,split
# notdrowsy/002_glasses_nonsleepyCombination_0_notdrowsy.jpg,notdrowsy,2,glasses,nonsleepyCombination,0,train
# notdrowsy/002_noglasses_nonsleepyCombination_0_notdrowsy.jpg,notdrowsy,2,noglasses,nonsleepyCombination,0,train

# %% [markdown]
# **Expected:** Shows train.csv, val.csv, test.csv with sizes and first few rows

# %% [markdown]
# ## Step 6: Install Dependencies

# %%
# !pwd # chcecking true folder
# !ls -l
# Out:
# /content/nthu-driver-drowsiness-ROI
# total 36
# drwxr-xr-x 2 root root 4096 Nov 22 14:01 configs
# drwxr-xr-x 4 root root 4096 Nov 22 14:01 data
# drwxr-xr-x 2 root root 4096 Nov 22 14:02 datasets
# drwxr-xr-x 2 root root 4096 Nov 22 14:01 docs
# drwxr-xr-x 2 root root 4096 Nov 22 14:01 notebooks
# -rw-r--r-- 1 root root 3201 Nov 22 14:01 README.md
# drwxr-xr-x 3 root root 4096 Nov 22 14:01 reports
# -rw-r--r-- 1 root root  466 Nov 22 14:01 requirements.txt
# drwxr-xr-x 7 root root 4096 Nov 22 14:01 src

# %%
# Install PyTorch with CUDA support
# !pip install --index-url https://download.pytorch.org/whl/cu121 torch torchvision -U

# Install other requirements
# !pip install -r /content/nthu-driver-drowsiness-ROI/requirements.txt
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.24.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 4)) (0.24.0+cu126)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: scipy==1.11.4 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 6)) (1.11.4)
# Requirement already satisfied: scikit-learn==1.3.2 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: pandas==2.1.4 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 8)) (2.1.4)
# Requirement already satisfied: matplotlib==3.8.2 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 9)) (3.8.2)
# Requirement already satisfied: seaborn==0.13.2 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 10)) (0.13.2)
# Requirement already satisfied: tqdm==4.66.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 11)) (4.66.1)
# Requirement already satisfied: opencv-python==4.8.1.78 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 12)) (4.8.1.78)
# Requirement already satisfied: Pillow>=9.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 13)) (11.3.0)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 14)) (6.0.3)
# Requirement already satisfied: jupyterlab==4.1.6 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (4.1.6)
# Requirement already satisfied: notebook==7.1.2 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 18)) (7.1.2)
# Requirement already satisfied: ipykernel==6.29.5 in /usr/local/lib/python3.12/dist-packages (from -r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (6.29.5)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.3.2->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 7)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.3.2->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 7)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.1.4->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 8)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.1.4->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.1.4->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 8)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 9)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 9)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 9)) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.8.2->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 9)) (3.2.5)
# Requirement already satisfied: async-lru>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (3.1.6)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.12/dist-packages (from jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.14.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (6.5.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (5.7.1)
# Requirement already satisfied: comm>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (5.9.5)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.12/dist-packages (from ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (26.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (3.5)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (3.5.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.25.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.16.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.0.3->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (3.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (4.5.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.32.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.1.4->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx>=0.25.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (25.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.19.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.29.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel==6.29.5->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 19)) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.19.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.19.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (2.23)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab==4.1.6->-r /content/nthu-driver-drowsiness-ROI/requirements.txt (line 17)) (1.4.0)

# %% [markdown]
# **Note:** May see some warnings about version conflicts — these are usually harmless

# %% [markdown]
# ## Step 7: Verify CUDA PyTorch

# %%
import torch
print('PyTorch version:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU device:', torch.cuda.get_device_name(0))
    print('GPU memory:', torch.cuda.get_device_properties(0).total_memory / 1e9, 'GB')
else:
    print('WARNING: CUDA not available! Go enable GPU runtime.')
# Out:
# PyTorch version: 2.9.0+cu126
# CUDA available: True
# GPU device: NVIDIA L4
# GPU memory: 23.795204096 GB

# %% [markdown]
# **Expected:**
# - `CUDA available: True`
# - GPU device: Tesla T4, L4, or similar
#
# **If False:** Stop here and enable GPU runtime!

# %% [markdown]
# ## Step 8: Start Training (ResNet50 Baseline)
#
# This will take ~30-60 minutes depending on GPU

# %%
# !pwd
# %cd nthu-driver-drowsiness-ROI
# Out:
# /content
# /content/nthu-driver-drowsiness-ROI

# %%
# Train with full baseline config (224px, 50 epochs with early stopping)
# !python src/training/train_baseline.py --config configs/baseline_efficientnet_b0.yaml --device cuda
# Out:
# Loading config from configs/baseline_efficientnet_b0.yaml
# Set random seed to 42
# Using device: cuda
#
# Creating data transforms...
# Creating dataloaders...
# Loaded 25572 samples from data/splits/train.csv
# Label distribution: {'drowsy': 13359, 'notdrowsy': 12213}
# Loaded 19016 samples from data/splits/val.csv
# Label distribution: {'drowsy': 9584, 'notdrowsy': 9432}
# Loaded 21933 samples from data/splits/test.csv
# Label distribution: {'drowsy': 13087, 'notdrowsy': 8846}
#   Train batches: 799
#   Val batches:   595
#   Test batches:  686
#
# Creating model: efficientnet_b0
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100% 20.5M/20.5M [00:00<00:00, 196MB/s]
#   Total parameters: 4,010,110
#   Trainable parameters: 4,010,110
#
# Initializing trainer...
#
# ============================================================
# Starting training: efficientnet_b0_baseline
# ============================================================
#
# Epoch 1 [Train]:   1% 10/799 [02:44<3:35:53, 16.42s/it, loss=0.6814, lr=0.000100]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 732, in __next__
#     data = self._next_data()
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1482, in _next_data
#     idx, data = self._get_data()
#                 ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1434, in _get_data
#     success, data = self._try_get_data()
#                     ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 1275, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/queue.py", line 180, in get
#     self.not_empty.wait(remaining)
#   File "/usr/lib/python3.12/threading.py", line 359, in wait
#     gotit = waiter.acquire(True, timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/nthu-driver-drowsiness-ROI/src/training/train_baseline.py", line 128, in <module>
#     main()
#   File "/content/nthu-driver-drowsiness-ROI/src/training/train_baseline.py", line 122, in main
#     trainer.train(num_epochs)
#   File "/content/nthu-driver-drowsiness-ROI/src/training/trainer.py", line 286, in train
#     train_metrics = self.train_epoch()
#                     ^^^^^^^^^^^^^^^^^^
#   File "/content/nthu-driver-drowsiness-ROI/src/training/trainer.py", line 127, in train_epoch
#     for batch_idx, (images, labels, metadata) in enumerate(pbar):
#                                                  ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1182, in __iter__
#     for obj in iterable:
#                ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py", line 728, in __next__
#     with torch.autograd.profiler.record_function(self._profile_name):
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/profiler.py", line 801, in __exit__
#     torch.ops.profiler._record_function_exit._RecordFunction(record)
#   File "/usr/local/lib/python3.12/dist-packages/torch/_ops.py", line 1068, in __call__
#     def __call__(self, /, *args: _P.args, **kwargs: _P.kwargs) -> _T:
#
# KeyboardInterrupt

# %% [markdown]
# **What to expect:**
# - Progress bars for each epoch
# - Training loss should decrease over time
# - Validation metrics printed after each epoch
# - Early stopping may trigger before 50 epochs if val metric plateaus
# - Checkpoints saved to `checkpoints/baseline_resnet50_best.pth` and `_last.pth`

# %% [markdown]
# ## Step 9: Verify Checkpoints

# %%
# !ls -lh checkpoints/
# Out:
# ls: cannot access 'checkpoints/': No such file or directory

# %% [markdown]
# **Expected:** Should see `baseline_resnet50_best.pth` and `baseline_resnet50_last.pth` (~90 MB each)

# %% [markdown]
# ## Step 10: Evaluate on Test Set

# %%
import torch
from src.models.classifier import create_model
from src.data.transforms import get_val_transforms
from src.data.dataset import create_dataloaders
from src.utils.config import get_config
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

# Load config
cfg = get_config("configs/baseline_resnet50.yaml")
cfg.data.num_workers = 2  # Colab-friendly

# Create test dataloader
val_tf = get_val_transforms(cfg.data.image_size)
loaders = create_dataloaders(
    cfg.data.train_csv, cfg.data.val_csv, cfg.data.test_csv,
    data_root=cfg.data.data_root,
    train_transform=val_tf,
    val_transform=val_tf,
    batch_size=cfg.data.batch_size,
    num_workers=cfg.data.num_workers
)

# Load model with best checkpoint
model = create_model(cfg)
ckpt = torch.load("checkpoints/baseline_resnet50_best.pth", map_location="cuda")
model.load_state_dict(ckpt['model_state'])
model.cuda().eval()

print("Best checkpoint from epoch:", ckpt.get('epoch', 'unknown'))
print("Best val macro-F1:", ckpt.get('val_macro_f1', 'unknown'))
print("\nEvaluating on test set...")

# Run inference on test set
all_preds, all_labels = [], []
with torch.no_grad():
    for images, labels, _ in loaders['test']:
        images = images.cuda()
        outputs = model(images)
        preds = outputs.argmax(1).cpu()
        all_preds.append(preds)
        all_labels.append(labels)

all_preds = torch.cat(all_preds).numpy()
all_labels = torch.cat(all_labels).numpy()

# Print metrics
print("\n" + "="*60)
print("TEST SET RESULTS")
print("="*60)
print(classification_report(all_labels, all_preds, target_names=['notdrowsy', 'drowsy']))
print("\nConfusion Matrix:")
print(confusion_matrix(all_labels, all_preds))
print("\n[Row: True label | Column: Predicted label]")
print("[0=notdrowsy, 1=drowsy]")

# %% [markdown]
# ## Step 11: Copy Checkpoints to Drive (for backup)

# %%
# Create backup directory on Drive
# !mkdir -p /content/drive/MyDrive/drowsiness-results/checkpoints

# Copy checkpoints
# !cp checkpoints/baseline_resnet50_best.pth /content/drive/MyDrive/drowsiness-results/checkpoints/
# !cp checkpoints/baseline_resnet50_last.pth /content/drive/MyDrive/drowsiness-results/checkpoints/

print("✅ Checkpoints backed up to Drive!")

# %% [markdown]
# ## Step 12: Download Checkpoints (Optional)
#
# If you want to download directly to your computer:

# %%
from google.colab import files

# Create a zip of checkpoints
# !zip -r baseline_resnet50_checkpoints.zip checkpoints/baseline_resnet50_*.pth

# Download the zip
files.download('baseline_resnet50_checkpoints.zip')

# %% [markdown]
# ## Next Steps
#
# After successful training:
#
# 1. **Download checkpoints** to your local machine
# 2. **Train EfficientNet-B0 baseline** for comparison:
#    ```python
#    !python src/training/train_baseline.py --config configs/baseline_efficientnet.yaml --device cuda
#    ```
# 3. **Compare results** and create performance tables
# 4. **Begin ROI implementation** (next phase)
#
# ---
#
# **Troubleshooting:**
# - **CUDA not available:** Enable GPU runtime
# - **Dataset not found:** Check Drive path in symlink command
# - **Out of memory:** Reduce batch_size in config
# - **Import errors:** Re-run pip install cell

# %%
# 13. Prevent Overfitting: Regularized Config
from pathlib import Path
regularized_yaml = Path('configs/baseline_resnet50_regularized.yaml')
regularized_yaml.write_text('''\
model:
  name: "resnet50"
  architecture: "resnet50"
  pretrained: true
  num_classes: 2
  freeze_backbone: true
  dropout: 0.7

data:
  data_root: "datasets"
  train_csv: "data/splits/train.csv"
  val_csv: "data/splits/val.csv"
  test_csv: "data/splits/test.csv"
  image_size: 224
  batch_size: 32
  num_workers: 2
  pin_memory: true

augmentation:
  enabled: true

training:
  epochs: 30
  optimizer: "adam"
  learning_rate: 0.00005
  weight_decay: 0.0005
  lr_scheduler:
    type: "reduce_on_plateau"
    mode: "max"
    factor: 0.5
    patience: 4
    min_lr: 0.000001
  loss:
    type: "weighted_cross_entropy"
    use_class_weights: true
  early_stopping:
    enabled: true
    patience: 5
    monitor: "val_macro_f1"
    mode: "max"
  gradient_clipping:
    enabled: true
    max_norm: 1.0

logging:
  experiment_name: "baseline_resnet50_regularized"
  log_dir: "runs"
  save_dir: "checkpoints"
  save_best_only: true
  save_last: true

seed: 42
device: "cuda"
''')
print(f'Wrote {regularized_yaml}')

# %%
# 14. Train Regularized Baseline (GPU)
# !python src/training/train_baseline.py --config configs/baseline_resnet50_regularized.yaml --device cuda

# %%
# 15. Evaluate Regularized Model on Test Set (metrics + plots)
# !python src/eval/evaluate_checkpoint.py --config configs/baseline_resnet50_regularized.yaml --device cuda --save-fig --save-preds

# %%
# 16. Save & Download Regularized Run Artifacts
# !zip -r baseline_results_regularized.zip checkpoints/baseline_resnet50_regularized_* runs/baseline_resnet50_regularized/ -q || echo "zip complete"
from google.colab import files
files.download('baseline_results_regularized.zip')

# %%
# 17. Train EfficientNet-B0 Baseline (GPU)
# !python src/training/train_baseline.py --config configs/baseline_efficientnet.yaml --device cuda

# %%
# 18. Evaluate EfficientNet-B0 on Test Set (metrics + plots)
# !python src/eval/evaluate_checkpoint.py --config configs/baseline_efficientnet.yaml --device cuda --save-fig --save-preds

# %%
# 19. Save & Download EfficientNet-B0 Artifacts
# !zip -r efficientnet_b0_results.zip checkpoints/baseline_efficientnet_b0_* runs/baseline_efficientnet_b0/ -q || echo "zip complete"
from google.colab import files
files.download('efficientnet_b0_results.zip')

# %%
# 20. Compare Baselines: ResNet50 vs Regularized vs EfficientNet-B0
from pathlib import Path
import json, pandas as pd, numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

experiments = [
    ("ResNet50 (baseline)", Path('runs/baseline_resnet50/metrics_test.json')),
    ("ResNet50 (regularized)", Path('runs/baseline_resnet50_regularized/metrics_test.json')),
    ("EfficientNet-B0", Path('runs/baseline_efficientnet_b0/metrics_test.json')),
]

rows = []
missing = []
for name, mpath in experiments:
    if mpath.exists():
        with open(mpath, 'r', encoding='utf-8') as f:
            m = json.load(f)
        roc_auc = m.get('roc_auc', {})
        if isinstance(roc_auc, dict) and roc_auc:
            roc_macro = float(np.mean([float(v) for v in roc_auc.values()]))
        else:
            roc_macro = np.nan
        rows.append({
            'experiment': name,
            'accuracy': float(m.get('accuracy', np.nan)),
            'macro_f1': float(m.get('f1_macro', np.nan)),
            'precision_macro': float(m.get('precision_macro', np.nan)),
            'recall_macro': float(m.get('recall_macro', np.nan)),
            'roc_auc_macro': roc_macro,
            'source': str(mpath),
        })
    else:
        missing.append((name, str(mpath)))

if missing:
    print("Missing metrics (run those evaluations first):")
    for n, p in missing:
        print(f" - {n}: {p}")

df = pd.DataFrame(rows)
if not df.empty:
    display(df.sort_values('macro_f1', ascending=False).reset_index(drop=True))
    # Plot Macro-F1 and Accuracy
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    order = df.sort_values('macro_f1', ascending=False)['experiment']
    sns.barplot(data=df, x='experiment', y='macro_f1', order=order, ax=axes[0], palette='Blues_d')
    axes[0].set_title('Macro-F1 (Test)')
    axes[0].set_ylim(0, 1)
    axes[0].set_xlabel('')
    axes[0].set_ylabel('Macro-F1')
    axes[0].tick_params(axis='x', rotation=20)

    sns.barplot(data=df, x='experiment', y='accuracy', order=order, ax=axes[1], palette='Greens_d')
    axes[1].set_title('Accuracy (Test)')
    axes[1].set_ylim(0, 1)
    axes[1].set_xlabel('')
    axes[1].set_ylabel('Accuracy')
    axes[1].tick_params(axis='x', rotation=20)

    fig.tight_layout()
    out_dir = Path('reports/figures')
    out_dir.mkdir(parents=True, exist_ok=True)
    out_png = out_dir / 'comparison_baselines.png'
    fig.savefig(out_png, dpi=150)
    print(f'Saved comparison figure to {out_png}')
else:
    print('No metrics found to compare yet.')

# %% [markdown]
# ## Speed Up: Copy Dataset to Local SSD
# On Colab, reading from Drive symlinks is slow. Copy the dataset once to the VM's local disk for faster DataLoader performance.

# %%
# Link dataset from Drive (run once per session if symlink not present)
# %cd /content/nthu-driver-drowsiness-ROI
import pathlib
root = pathlib.Path('datasets')
drive = pathlib.Path('/content/drive/MyDrive/datasets')
if root.is_symlink() and root.resolve() == drive:
    print('Symlink already exists: datasets ->', drive)
elif root.exists() and not root.is_symlink():
    print('Local datasets directory already exists (not a symlink). Using it as-is.')
elif drive.exists():
    root.symlink_to(drive, target_is_directory=True)
    print('✅ Symlink created: datasets -> /content/drive/MyDrive/datasets')
else:
    raise FileNotFoundError('Drive dataset not found at /content/drive/MyDrive/datasets')
# !ls -lh datasets | head -5

# %% [markdown]
# ## Set DataLoader Workers to 2 (Colab-friendly)
# Colab often warns about too many workers. This patches the baseline YAML to use 2 workers and the local dataset path.

# %%
import yaml, pathlib
p = pathlib.Path('configs/baseline_resnet50.yaml')
cfg = yaml.safe_load(p.read_text())
cfg.setdefault('data', {})
cfg['data']['num_workers'] = 2
cfg['data']['data_root'] = 'datasets'
cfg['data']['pin_memory'] = True
p.write_text(yaml.safe_dump(cfg, sort_keys=False))
print('✅ Updated', p)
print('num_workers:', cfg['data']['num_workers'])
print('data_root:', cfg['data']['data_root'])

# %% [markdown]
# ## Resume Tomorrow: Quick Checklist
# - Step 1: Enable GPU and run the GPU check.
# - Step 2: Mount Drive.
# - Step 3: Ensure a symlink `datasets -> /content/drive/MyDrive/datasets` exists (run link cell if missing).
# - Step 4: Ensure `num_workers: 2` and `data_root: datasets` in YAML (patch cell above).
# - Step 5: Start training (regularized config recommended):
#   - `!python src/training/train_baseline.py --config configs/baseline_resnet50_regularized.yaml --device cuda`
# - Optional: Evaluate best checkpoint when done:
#   - `!python src/eval/evaluate_checkpoint.py --config configs/baseline_resnet50_regularized.yaml --device cuda --save-fig --save-preds`
# - Tip: If time is short, try `configs/baseline_efficientnet.yaml` for a lighter model.
